# %% [markdown]
# -sandbox
# <img width = '500' src="https://databricks.com/wp-content/uploads/2021/06/db-pride-logo.svg" style="float: left: margin: 30px"/>        <img src="https://files.training.databricks.com/images/Apache-Spark-Logo_TM_200px.png" style="float: left: margin: 10px"/>
#
# <br>
# > # Raw para Bronze
#
# <br>
# ## 04 - Transações de estoque
#
# Outro conjunto de dados transacionais são pedidos de estoque ou transações de estoque.
#
# Os dados de Pedidos de Estoque são gerados pelas atividades de compra, venda e cliques de clientes no site. O tempo gasto em um ticker quando um investidor executa uma análise usando a ferramenta de análise (por exemplo, ao verificar sua série temporal para ver como o preço estava mudando ao longo do tempo) pode ser rastreado.
#
# Isso gera informações valiosas, porque podemos presumir que eles vão comprar.
#
# - As Solicitações de Empréstimo são um conjunto de dados transacionais gerado por investidores que precisam de créditos.
# - Se aprovados, eles podem usar esses créditos (ou fundos) para fins de investimento.
# - A aprovação depende muito da pontuação de crédito do investidor.
# - As solicitações de empréstimo vêm por meio de uma exportação XML.
#
# ## Objetivos:
#  * Ler arquivo JSON em um Spark DataFrame
#  * Criar tabela Delta a partir da fonte de dados

# %% [markdown]
# -sandbox
# <h2 style="color:red">Informações:</h2>
#
# - ainda estamos trabalhando com tabelas de nível bronze

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Etapas a serem concluídas:
#
# <br>
# - Leia o arquivo em ** `stockOrdersPath` ** em um DataFrame.
# - Exibir o DataFrame com apenas **3** registros.
# - Imprima o esquema do DataFrame.
# - Grave o DataFrame final como uma tabela Delta em ** `targetDirectory` **.
#    - Certifique-se de permitir que o Spark sobrescreva o local de destino, se necessário, e também use a opção para sobrescrever esquema.
# - Retorne o DataFrame final, que deve ter o seguinte esquema:
#
# |name|type|
# |---|---|
# |clicked_items|ArrayType|
# |investor|LongType|
# |ordertime|LongType|
# |price|DoubleType|
# |ticker|StringType|
# |transaction_id|LongType|
# |type|StringType|
# |volume|LongType|

# %%
def func_TranEmp(spark, stockOrdersPath, targetDirectory):
  
  
  # Lê o arquivo em stockOrdersPath para um DataFrame
  df = (spark.read
             .json(stockOrdersPath))
  
  
  # Exibe o DataFrame usando show(3)
  df.show(3)
  
  
  # Exibe o esquema do DataFrame
  df.printSchema()
  
  
  # Grava o DataFrame final como uma tabela Delta em targetDirectory
  # Sobrescrever o local de destino "overwrite"
  # Sobrescrever o Schema
  (df.write
     .mode("overwrite")
     .option("overwriteSchema", True)
     .format("delta")
     .save(targetDirectory))
  
  
  return df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfFinal = func_TranEmp(spark, stockOrdersPath, targetDirectory)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------+----------+------------------+------+--------------+----+------+
#        clicked_items|investor| ordertime|             price|ticker|transaction_id|type|volume|
# +--------------------+--------+----------+------------------+------+--------------+----+------+
# [[LKQ, 10], [QRVO...|    1101|1567328400|            111.57|  ADSK|     581346329| BUY|     4|
#          [[COP, 10]]|    1036|1567328497|111.31066104190633|  ADSK|     581346330| BUY|    12|
# [[ETFC, 50], [EVH...|      24|1567329557|112.08980474076839|  ADSK|     581346331| BUY|    12|
# +--------------------+--------+----------+------------------+------+--------------+----+------+
# only showing top 3 rows
#
# root
# -- clicked_items: array (nullable = true)
#     |-- element: array (containsNull = true)
#     |    |-- element: string (containsNull = true)
# -- investor: long (nullable = true)
# -- ordertime: long (nullable = true)
# -- price: double (nullable = true)
# -- ticker: string (nullable = true)
# -- transaction_id: long (nullable = true)
# -- type: string (nullable = true)
# -- volume: long (nullable = true)
#
# </div>

# %%
display(dfFinal)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>clicked_items</th><th>investor</th><th>ordertime</th><th>price</th><th>ticker</th><th>transaction_id</th><th>type</th><th>volume</th></tr></thead><tbody><tr><td>List(List(LKQ, 10), List(QRVO, 30))</td><td>1101</td><td>1567328400</td><td>111.57</td><td>ADSK</td><td>581346329</td><td>BUY</td><td>4</td></tr><tr><td>List(List(COP, 10))</td><td>1036</td><td>1567328497</td><td>111.31066104190633</td><td>ADSK</td><td>581346330</td><td>BUY</td><td>12</td></tr><tr><td>List(List(ETFC, 50), List(EVHC, 50), List(IR, 32))</td><td>24</td><td>1567329557</td><td>112.08980474076839</td><td>ADSK</td><td>581346331</td><td>BUY</td><td>12</td></tr><tr><td>List(List(PM, 17))</td><td>722</td><td>1567330523</td><td>111.32084465666814</td><td>ADSK</td><td>581346332</td><td>BUY</td><td>12</td></tr><tr><td>List(List(CBOE, 33), List(NDAQ, 10), List(HCN, 31))</td><td>203</td><td>1567330570</td><td>111.85157483553013</td><td>ADSK</td><td>581346333</td><td>BUY</td><td>5</td></tr><tr><td>List(List(RSG, 47), List(ADBE, 40), List(ALLE, 46))</td><td>608</td><td>1567331046</td><td>111.6824514218388</td><td>ADSK</td><td>581346334</td><td>BUY</td><td>6</td></tr><tr><td>List(List(PKG, 21))</td><td>409</td><td>1567331224</td><td>111.69668307782608</td><td>ADSK</td><td>581346335</td><td>SELL</td><td>22</td></tr><tr><td>List(List(REGN, 7), List(PAYX, 5))</td><td>1122</td><td>1567331358</td><td>111.72609213357298</td><td>ADSK</td><td>581346336</td><td>SELL</td><td>10</td></tr><tr><td>List(List(AAL, 35))</td><td>821</td><td>1567331554</td><td>111.39436879446667</td><td>ADSK</td><td>581346337</td><td>BUY</td><td>14</td></tr><tr><td>List(List(PPL, 18), List(COTY, 29), List(ANDV, 11))</td><td>836</td><td>1567331816</td><td>111.48294271642783</td><td>ADSK</td><td>581346338</td><td>SELL</td><td>2</td></tr><tr><td>List(List(PRGO, 50), List(BDX, 12))</td><td>661</td><td>1567332374</td><td>111.24273885231108</td><td>ADSK</td><td>581346339</td><td>BUY</td><td>3</td></tr><tr><td>List(List(URI, 17))</td><td>462</td><td>1567332454</td><td>111.76945039914756</td><td>ADSK</td><td>581346340</td><td>BUY</td><td>2</td></tr><tr><td>List(List(XRX, 34), List(VRTX, 15))</td><td>1043</td><td>1567332625</td><td>111.3749246955606</td><td>ADSK</td><td>581346341</td><td>SELL</td><td>7</td></tr><tr><td>List(List(NLSN, 28))</td><td>391</td><td>1567332677</td><td>111.99874726678271</td><td>ADSK</td><td>581346342</td><td>BUY</td><td>22</td></tr><tr><td>List(List(CME, 12))</td><td>645</td><td>1567333017</td><td>111.60598684013895</td><td>ADSK</td><td>581346343</td><td>BUY</td><td>27</td></tr><tr><td>List(List(PKG, 33))</td><td>1170</td><td>1567333381</td><td>111.08495554577712</td><td>ADSK</td><td>581346344</td><td>BUY</td><td>27</td></tr><tr><td>List(List(EBAY, 19), List(HBAN, 28))</td><td>528</td><td>1567334081</td><td>111.55010355934935</td><td>ADSK</td><td>581346345</td><td>SELL</td><td>8</td></tr><tr><td>List(List(MDLZ, 7), List(INFO, 34), List(CTXS, 6))</td><td>38</td><td>1567334303</td><td>111.881041916481</td><td>ADSK</td><td>581346346</td><td>BUY</td><td>2</td></tr><tr><td>List(List(FMC, 6))</td><td>984</td><td>1567334484</td><td>111.76004204740651</td><td>ADSK</td><td>581346347</td><td>BUY</td><td>9</td></tr><tr><td>List(List(UNM, 32), List(RSG, 7))</td><td>706</td><td>1567334566</td><td>112.03184363597003</td><td>ADSK</td><td>581346348</td><td>BUY</td><td>27</td></tr><tr><td>List(List(AIG, 49), List(ED, 47), List(EMR, 40))</td><td>1357</td><td>1567335069</td><td>111.72990051319107</td><td>ADSK</td><td>581346349</td><td>BUY</td><td>12</td></tr><tr><td>List(List(PBCT, 38), List(DVN, 48), List(PGR, 39))</td><td>994</td><td>1567335136</td><td>110.91184489949394</td><td>ADSK</td><td>581346350</td><td>SELL</td><td>8</td></tr><tr><td>List(List(PYPL, 50))</td><td>55</td><td>1567336099</td><td>111.794345411136</td><td>ADSK</td><td>581346351</td><td>SELL</td><td>17</td></tr><tr><td> ...

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Qualidade dos dados</h2>

# %%
assert \
      (spark.read
            .json(stockOrdersPath)
            .count()) \
== \
      (dfFinal.count()) \
, displayHTML("""<font size="5" color="red" face="sans-serif">Validação: falhou !!!</font>""")

displayHTML("""<font size="5" color="green" face="sans-serif">Validação: correta !!!</font>""")
# Out:
# <font size="5" color="green" face="sans-serif">Validação: correta !!!</font>

# %%
from pyspark.sql.types import StructType, StructField, LongType, StringType, DoubleType, ArrayType

schemaOriginal = (StructType([
                               StructField("clicked_items"   ,ArrayType(ArrayType(StringType(), True), True), True),
                               StructField("investor"        ,LongType()   ,True),
                               StructField("ordertime"       ,LongType()   ,True),
                               StructField("price"           ,DoubleType() ,True),
                               StructField("ticker"          ,StringType() ,True),
                               StructField("transaction_id"  ,LongType()   ,True),
                               StructField("type"            ,StringType() ,True),
                               StructField("volume"          ,LongType()   ,True)
                              ]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
assert dfFinal.schema == schemaOriginal, displayHTML("""<font size="5" color="red" face="sans-serif">Validação: falhou !!!</font>""")

displayHTML("""<font size="5" color="green" face="sans-serif">Validação: correta !!!</font>""")
# Out:
# <font size="5" color="green" face="sans-serif">Validação: correta !!!</font>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Validação</h2>

# %%
realityCheck(func_TranEmp, spark, stockOrdersPath, targetDirectory)
# Out:
# <style>
#   table { text-align: left; border-collapse: collapse; margin: 1em; caption-side: bottom; font-family: Sans-Serif; font-size: 16px}
#   caption { text-align: left; padding: 5px }
#   th, td { border: 1px solid #ddd; padding: 5px }
#   th { background-color: #ddd }
#   .passed { background-color: #97d897 }
#   .failed { background-color: #e2716c }
#   .skipped { background-color: #f9d275 }
#   .results .points { display: none }
#   .results .message { display: none }
#   .results .passed::before  { content: "Passed" }
#   .results .failed::before  { content: "Failed" }
#   .results .skipped::before { content: "Skipped" }
#   .grade .passed  .message:empty::before { content:"Passed" }
#   .grade .failed  .message:empty::before { content:"Failed" }
#   .grade .skipped .message:empty::before { content:"Skipped" }
# </style>
# <table class='results'>
#   <tr><th class='points'>Points</th><th class='test'>Test</th><th class='result'>Result</th></tr>
#   <tr><td class='points'>1</td><td class='test'>Returns correct schema</td><td class='result passed'><span class='message'></span></td></tr>
#   <tr><td class='points'>1</td><td class='test'>Returns DataFrame with correct number of rows</td><td class='result passed'><span class='message'></span></td></tr>
#   <tr><td class='points'>1</td><td class='test'>Returns DataFrame with correct results</td><td class='result passed'><span class='message'></span></td></tr>
#   <tr><td class='points'>1</td><td class='test'>Prints expected output</td><td class='result passed'><span class='message'></span></td></tr>
#   <tr><td class='points'>1</td><td class='test'>Delta Table in place</td><td class='result passed'><span class='message'></span></td></tr>
#   <tr><td class='points'>1</td><td class='test'>Delta Table has correct contents</td><td class='result passed'><span class='message'></span></td></tr>
#   <caption class='points'>Score: 6</caption>
# </table>

# %% [markdown]
# ## <img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Próximo <p>
#
# > * [Dados Macro]($./05-Dados Macro)

# %% [markdown]
# -sandbox
#
# <a href="http://www.apache.org/">Apache Software Foundation</a> <p>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a>
